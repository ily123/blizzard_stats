# %% [markdown]
# ### Introduction
#
# The goal of this analysis is to evaluate M+ class balance in Blizzard Activision's MMORPG World of Warcraft.
#
# ### Thing I want to learn
# -Change in tank class representation over time<br>
# -Change in healer class representation<br>
# -Change in dps class representation (melee/range)<br>
# -Shift between melee-heavy and range-heavy compositions<br>
# -Most represented affixes (season by season, and overall)<br>
# -Most represented team compositions<br>

# %%
import requests
import pandas as pd
import time
import pickle
from collections import OrderedDict


pd.options.display.max_columns = 100

# %%
# use raider.io API to query top 100 runs for every dungeon

url = 'https://raider.io/api/v1/mythic-plus/runs?season=season-7.3.0&region=world&dungeon=eye-of-azshara&page=4'
resp = requests.get(url)
print(resp.status_code)
# Out:
# 200

# %%
resp_dict = resp.json()

# %%
resp_dict
# Out:
# {'rankings': [{'rank': 81,
#    'score': 287.83373648085717,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 2295992,
#     'keystone_team_id': 5363385,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1879280,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-10-18T06:57:27.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 221719,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 5,
#       'icon': 'spell_nature_massteleport',
#       'name': 'Teeming',
#       'description': 'Additional non-boss enemies are present throughout the dungeon.'},
#      {'id': 14,
#       'icon': 'spell_nature_earthquake',
#       'name': 'Quaking',
#       'description': 'Periodically, all players emit a shockwave, inflicting damage and interrupting nearby allies.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 28993,
#        'persona_id': 5333,
#        'name': 'Jdotb-28993',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/us/illidan/Jdotb-28993',
#        'realm': {'id': 369,
#         'connectedRealmId': 207,
#         'name': 'Illidan',
#         'altName': None,
#         'slug': 'illidan',
#         'altSlug': 'illidan',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 212772,
#        'persona_id': 44161,
#        'name': 'Marvink',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Destruction', 'slug': 'destruction'},
#        'path': '/characters/us/area-52/Marvink',
#        'realm': {'id': 264,
#         'connectedRealmId': 136,
#         'name': 'Area 52',
#         'altName': None,
#         'slug': 'area-52',
#         'altSlug': 'area-52',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 323418,
#        'persona_id': 243088,
#        'name': 'Shakib-323418',
#        'class': {'id': 12, 'name': 'Demon Hunter', 'slug': 'demon-hunter'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Havoc', 'slug': 'havoc'},
#        'path': '/characters/us/turalyon/Shakib-323418',
#        'realm': {'id': 472,
#         'connectedRealmId': 238,
#         'name': 'Turalyon',
#         'altName': None,
#         'slug': 'turalyon',
#         'altSlug': 'turalyon',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 1037382,
#        'persona_id': 2660542,
#        'name': 'Fûryz-1037382',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/us/tichondrius/Fûryz-1037382',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 9252034,
#        'persona_id': 4320118,
#        'name': 'Dossouzed-9252034',
#        'class': {'id': 3, 'name': 'Hunter', 'slug': 'hunter'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Marksmanship', 'slug': 'marksmanship'},
#        'path': '/characters/us/illidan/Dossouzed-9252034',
#        'realm': {'id': 369,
#         'connectedRealmId': 207,
#         'name': 'Illidan',
#         'altName': None,
#         'slug': 'illidan',
#         'altSlug': 'illidan',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 82,
#    'score': 287.79444795574227,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3811777,
#     'keystone_team_id': 3944588,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1882719,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-20T16:20:32.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 218280,
#     'faction': 'alliance',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'When injured below 90% health, players will suffer increasing damage over time until healed above 90% health.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 346882,
#        'persona_id': 321713,
#        'name': 'Jazu-346882',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 116,
#        'spec': {'name': 'Subtlety', 'slug': 'subtlety'},
#        'path': '/characters/us/frostmourne/Jazu-346882',
#        'realm': {'id': 345,
#         'connectedRealmId': 192,
#         'name': 'Frostmourne',
#         'altName': None,
#         'slug': 'frostmourne',
#         'altSlug': 'frostmourne',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 346906,
#        'persona_id': 321733,
#        'name': 'Levilee',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Retribution', 'slug': 'retribution'},
#        'path': '/characters/us/frostmourne/Levilee',
#        'realm': {'id': 345,
#         'connectedRealmId': 192,
#         'name': 'Frostmourne',
#         'altName': None,
#         'slug': 'frostmourne',
#         'altSlug': 'frostmourne',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'healer'},
#      {'character': {'id': 346947,
#        'persona_id': 321771,
#        'name': 'Spiderbearz',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/us/frostmourne/Spiderbearz',
#        'realm': {'id': 345,
#         'connectedRealmId': 192,
#         'name': 'Frostmourne',
#         'altName': None,
#         'slug': 'frostmourne',
#         'altSlug': 'frostmourne',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 347003,
#        'persona_id': 6988331,
#        'name': 'Exshack',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Unholy', 'slug': 'unholy'},
#        'path': '/characters/us/frostmourne/Exshack',
#        'realm': {'id': 345,
#         'connectedRealmId': 192,
#         'name': 'Frostmourne',
#         'altName': None,
#         'slug': 'frostmourne',
#         'altSlug': 'frostmourne',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'tank'},
#      {'character': {'id': 7480520,
#        'persona_id': 3270167,
#        'name': 'Landyachtzs-7480520',
#        'class': {'id': 8, 'name': 'Mage', 'slug': 'mage'},
#        'race': {'id': 3,
#         'name': 'Dwarf',
#         'slug': 'dwarf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Frost', 'slug': 'frost'},
#        'path': '/characters/us/frostmourne/Landyachtzs-7480520',
#        'realm': {'id': 345,
#         'connectedRealmId': 192,
#         'name': 'Frostmourne',
#         'altName': None,
#         'slug': 'frostmourne',
#         'altSlug': 'frostmourne',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 83,
#    'score': 287.79098661842653,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3849815,
#     'keystone_team_id': 6800526,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1883022,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-21T17:48:03.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 217977,
#     'faction': 'alliance',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'When injured below 90% health, players will suffer increasing damage over time until healed above 90% health.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 354486,
#        'persona_id': 247297,
#        'name': 'Fidonlol',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 30,
#         'name': 'Lightforged Draenei',
#         'slug': 'lightforged-draenei',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Retribution', 'slug': 'retribution'},
#        'path': '/characters/eu/silvermoon/Fidonlol',
#        'realm': {'id': 704,
#         'connectedRealmId': 355,
#         'name': 'Silvermoon',
#         'altName': None,
#         'slug': 'silvermoon',
#         'altSlug': 'silvermoon',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 4073227,
#        'persona_id': 1130409,
#        'name': 'Celalinda',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/antonidas/Celalinda',
#        'realm': {'id': 506,
#         'connectedRealmId': 253,
#         'name': 'Antonidas',
#         'altName': None,
#         'slug': 'antonidas',
#         'altSlug': 'antonidas',
#         'locale': 'de_DE',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'tank'},
#      {'character': {'id': 5356706,
#        'persona_id': 1436533,
#        'name': 'Gothedark-5356706',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/gorgonnash/Gothedark-5356706',
#        'realm': {'id': 615,
#         'connectedRealmId': 302,
#         'name': 'Gorgonnash',
#         'altName': None,
#         'slug': 'gorgonnash',
#         'altSlug': 'gorgonnash',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 9328771,
#        'persona_id': 9346561,
#        'name': 'Delarí-9328771',
#        'class': {'id': 8, 'name': 'Mage', 'slug': 'mage'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Fire', 'slug': 'fire'},
#        'path': '/characters/eu/sylvanas/Delarí-9328771',
#        'realm': {'id': 716,
#         'connectedRealmId': 358,
#         'name': 'Sylvanas',
#         'altName': None,
#         'slug': 'sylvanas',
#         'altSlug': 'sylvanas',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 11417366,
#        'persona_id': 247933,
#        'name': 'Tanìa-11417366',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/eu/silvermoon/Tanìa-11417366',
#        'realm': {'id': 704,
#         'connectedRealmId': 355,
#         'name': 'Silvermoon',
#         'altName': None,
#         'slug': 'silvermoon',
#         'altSlug': 'silvermoon',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'}],
#     'platoon': None}},
#   {'rank': 84,
#    'score': 287.77590801087945,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 2437142,
#     'keystone_team_id': 5492390,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1884342,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-10-21T04:09:53.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 216657,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 5,
#       'icon': 'spell_nature_massteleport',
#       'name': 'Teeming',
#       'description': 'Additional non-boss enemies are present throughout the dungeon.'},
#      {'id': 14,
#       'icon': 'spell_nature_earthquake',
#       'name': 'Quaking',
#       'description': 'Periodically, all players emit a shockwave, inflicting damage and interrupting nearby allies.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 3422886,
#        'persona_id': 963253,
#        'name': 'Revofevi-3422886',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Frost', 'slug': 'frost'},
#        'path': '/characters/us/bleeding-hollow/Revofevi-3422886',
#        'realm': {'id': 284,
#         'connectedRealmId': 154,
#         'name': 'Bleeding Hollow',
#         'altName': None,
#         'slug': 'bleeding-hollow',
#         'altSlug': 'bleeding-hollow',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 9311198,
#        'persona_id': 2110136,
#        'name': 'Wafflesauce',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/us/tichondrius/Wafflesauce',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 9545803,
#        'persona_id': 355504,
#        'name': 'Níghtfall',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/us/tichondrius/Níghtfall',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 10279382,
#        'persona_id': 173963,
#        'name': 'Maset-10279382',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/us/thrall/Maset-10279382',
#        'realm': {'id': 465,
#         'connectedRealmId': 235,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 10889440,
#        'persona_id': 1952885,
#        'name': 'Jøçtãã-10889440',
#        'class': {'id': 7, 'name': 'Shaman', 'slug': 'shaman'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Elemental', 'slug': 'elemental'},
#        'path': '/characters/us/stormreaver/Jøçtãã-10889440',
#        'realm': {'id': 453,
#         'connectedRealmId': 234,
#         'name': 'Stormreaver',
#         'altName': None,
#         'slug': 'stormreaver',
#         'altSlug': 'stormreaver',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 85,
#    'score': 287.7639713401993,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3129760,
#     'keystone_team_id': 6078499,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1885387,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-05T01:55:03.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 215612,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 7,
#       'icon': 'ability_warrior_battleshout',
#       'name': 'Bolstering',
#       'description': 'When any non-boss enemy dies, its death cry empowers nearby allies, increasing their maximum health and damage by 20%.'},
#      {'id': 2,
#       'icon': 'spell_magic_lesserinvisibilty',
#       'name': 'Skittish',
#       'description': 'Enemies pay far less attention to threat generated by tanks.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 3736684,
#        'persona_id': 1043077,
#        'name': 'Irüka',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 2, 'name': 'Orc', 'slug': 'orc', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Fury', 'slug': 'fury'},
#        'path': '/characters/eu/uldaman/Irüka',
#        'realm': {'id': 741,
#         'connectedRealmId': 311,
#         'name': 'Uldaman',
#         'altName': None,
#         'slug': 'uldaman',
#         'altSlug': 'uldaman',
#         'locale': 'fr_FR',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 4035264,
#        'persona_id': 1121564,
#        'name': 'Mithzz-4035264',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/twisting-nether/Mithzz-4035264',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 5530012,
#        'persona_id': 1459526,
#        'name': 'Drjaý-5530012',
#        'class': {'id': 8, 'name': 'Mage', 'slug': 'mage'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Fire', 'slug': 'fire'},
#        'path': '/characters/eu/twisting-nether/Drjaý-5530012',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 7503171,
#        'persona_id': 1861382,
#        'name': 'Sjeletyven-7503171',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/kazzak/Sjeletyven-7503171',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 11232651,
#        'persona_id': 1132121,
#        'name': 'Flyxx',
#        'class': {'id': 12, 'name': 'Demon Hunter', 'slug': 'demon-hunter'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Havoc', 'slug': 'havoc'},
#        'path': '/characters/eu/kazzak/Flyxx',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 86,
#    'score': 287.7507444882393,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 1887720,
#     'keystone_team_id': 4986949,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1886545,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-10-08T19:18:31.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 214454,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 3,
#       'icon': 'spell_shaman_lavasurge',
#       'name': 'Volcanic',
#       'description': 'While in combat, enemies periodically cause gouts of flame to erupt beneath the feet of distant players.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 73346,
#        'persona_id': 14690,
#        'name': 'Trailerpark-73346',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/kazzak/Trailerpark-73346',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 3373731,
#        'persona_id': 949255,
#        'name': 'Kenvoqt',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Outlaw', 'slug': 'outlaw'},
#        'path': '/characters/eu/blackrock/Kenvoqt',
#        'realm': {'id': 527,
#         'connectedRealmId': 273,
#         'name': 'Blackrock',
#         'altName': None,
#         'slug': 'blackrock',
#         'altSlug': 'blackrock',
#         'locale': 'de_DE',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 3373840,
#        'persona_id': 949326,
#        'name': 'Drégan-3373840',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/draenor/Drégan-3373840',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4929248,
#        'persona_id': 3002526,
#        'name': 'Bersyl-4929248',
#        'class': {'id': 12, 'name': 'Demon Hunter', 'slug': 'demon-hunter'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Vengeance', 'slug': 'vengeance'},
#        'path': '/characters/eu/dalaran/Bersyl-4929248',
#        'realm': {'id': 554,
#         'connectedRealmId': 291,
#         'name': 'Dalaran',
#         'altName': None,
#         'slug': 'dalaran',
#         'altSlug': 'dalaran',
#         'locale': 'fr_FR',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 8271981,
#        'persona_id': 1994522,
#        'name': 'Flapkingx-8271981',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/kazzak/Flapkingx-8271981',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 87,
#    'score': 287.746244298989,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3181663,
#     'keystone_team_id': 6182276,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1886939,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-06T05:24:26.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 214060,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 7,
#       'icon': 'ability_warrior_battleshout',
#       'name': 'Bolstering',
#       'description': 'When any non-boss enemy dies, its death cry empowers nearby allies, increasing their maximum health and damage by 20%.'},
#      {'id': 2,
#       'icon': 'spell_magic_lesserinvisibilty',
#       'name': 'Skittish',
#       'description': 'Enemies pay far less attention to threat generated by tanks.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 654462,
#        'persona_id': 132866,
#        'name': 'Potatopouch-654462',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Destruction', 'slug': 'destruction'},
#        'path': '/characters/us/barthilas/Potatopouch-654462',
#        'realm': {'id': 276,
#         'connectedRealmId': 146,
#         'name': 'Barthilas',
#         'altName': None,
#         'slug': 'barthilas',
#         'altSlug': 'barthilas',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 885921,
#        'persona_id': 170357,
#        'name': 'Ypfl-885921',
#        'class': {'id': 7, 'name': 'Shaman', 'slug': 'shaman'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Enhancement', 'slug': 'enhancement'},
#        'path': '/characters/us/dathremar/Ypfl-885921',
#        'realm': {'id': 308,
#         'connectedRealmId': 169,
#         'name': "Dath'Remar",
#         'altName': None,
#         'slug': 'dathremar',
#         'altSlug': 'dathremar',
#         'locale': 'en_US',
#         'isConnected': True},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 1283893,
#        'persona_id': 2374886,
#        'name': 'Lowbudget-1283893',
#        'class': {'id': 8, 'name': 'Mage', 'slug': 'mage'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Arcane', 'slug': 'arcane'},
#        'path': '/characters/us/jubeithos/Lowbudget-1283893',
#        'realm': {'id': 371,
#         'connectedRealmId': 202,
#         'name': "Jubei'Thos",
#         'altName': None,
#         'slug': 'jubeithos',
#         'altSlug': 'jubeithos',
#         'locale': 'en_US',
#         'isConnected': True},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4038772,
#        'persona_id': 1122640,
#        'name': 'Miraval-4038772',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Retribution', 'slug': 'retribution'},
#        'path': '/characters/us/barthilas/Miraval-4038772',
#        'realm': {'id': 276,
#         'connectedRealmId': 146,
#         'name': 'Barthilas',
#         'altName': None,
#         'slug': 'barthilas',
#         'altSlug': 'barthilas',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 6852400,
#        'persona_id': 3926232,
#        'name': 'Rimwaztok-6852400',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/us/barthilas/Rimwaztok-6852400',
#        'realm': {'id': 276,
#         'connectedRealmId': 146,
#         'name': 'Barthilas',
#         'altName': None,
#         'slug': 'barthilas',
#         'altSlug': 'barthilas',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 88,
#    'score': 287.7141282405914,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3728416,
#     'keystone_team_id': 6690135,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1889751,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-18T18:46:27.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 211248,
#     'faction': 'alliance',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'When injured below 90% health, players will suffer increasing damage over time until healed above 90% health.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 1087310,
#        'persona_id': 364820,
#        'name': 'Fasox',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/ravencrest/Fasox',
#        'realm': {'id': 689,
#         'connectedRealmId': 353,
#         'name': 'Ravencrest',
#         'altName': None,
#         'slug': 'ravencrest',
#         'altSlug': 'ravencrest',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 1105279,
#        'persona_id': 370572,
#        'name': 'Vichor-1105279',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Fury', 'slug': 'fury'},
#        'path': '/characters/eu/silvermoon/Vichor-1105279',
#        'realm': {'id': 704,
#         'connectedRealmId': 355,
#         'name': 'Silvermoon',
#         'altName': None,
#         'slug': 'silvermoon',
#         'altSlug': 'silvermoon',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 2098848,
#        'persona_id': 2480325,
#        'name': 'Baeshadezz-2098848',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/chamber-of-aspects/Baeshadezz-2098848',
#        'realm': {'id': 544,
#         'connectedRealmId': 285,
#         'name': 'Chamber of Aspects',
#         'altName': None,
#         'slug': 'chamber-of-aspects',
#         'altSlug': 'chamber-of-aspects',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 6488224,
#        'persona_id': 1663242,
#        'name': 'Pántsu-6488224',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Protection', 'slug': 'protection'},
#        'path': '/characters/eu/silvermoon/Pántsu-6488224',
#        'realm': {'id': 704,
#         'connectedRealmId': 355,
#         'name': 'Silvermoon',
#         'altName': None,
#         'slug': 'silvermoon',
#         'altSlug': 'silvermoon',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 11456252,
#        'persona_id': 2616264,
#        'name': 'Vøïd-11456252',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/the-maelstrom/Vøïd-11456252',
#        'realm': {'id': 725,
#         'connectedRealmId': 297,
#         'name': 'The Maelstrom',
#         'altName': None,
#         'slug': 'the-maelstrom',
#         'altSlug': 'the-maelstrom',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 89,
#    'score': 287.67991464873035,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3621496,
#     'keystone_team_id': 5375998,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1892747,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-16T15:56:27.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 208252,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'When injured below 90% health, players will suffer increasing damage over time until healed above 90% health.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 360040,
#        'persona_id': 322619,
#        'name': 'Broutbrout-360040',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/sargeras/Broutbrout-360040',
#        'realm': {'id': 695,
#         'connectedRealmId': 327,
#         'name': 'Sargeras',
#         'altName': None,
#         'slug': 'sargeras',
#         'altSlug': 'sargeras',
#         'locale': 'fr_FR',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 360060,
#        'persona_id': 322638,
#        'name': 'Lophh-360060',
#        'class': {'id': 5, 'name': 'Priest', 'slug': 'priest'},
#        'race': {'id': 9,
#         'name': 'Goblin',
#         'slug': 'goblin',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Discipline', 'slug': 'discipline'},
#        'path': '/characters/eu/sargeras/Lophh-360060',
#        'realm': {'id': 695,
#         'connectedRealmId': 327,
#         'name': 'Sargeras',
#         'altName': None,
#         'slug': 'sargeras',
#         'altSlug': 'sargeras',
#         'locale': 'fr_FR',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 1073455,
#        'persona_id': 208171,
#        'name': 'Toofastbb-1073455',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/sargeras/Toofastbb-1073455',
#        'realm': {'id': 695,
#         'connectedRealmId': 327,
#         'name': 'Sargeras',
#         'altName': None,
#         'slug': 'sargeras',
#         'altSlug': 'sargeras',
#         'locale': 'fr_FR',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4685539,
#        'persona_id': 1293514,
#        'name': 'Tactacboom-4685539',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/sargeras/Tactacboom-4685539',
#        'realm': {'id': 695,
#         'connectedRealmId': 327,
#         'name': 'Sargeras',
#         'altName': None,
#         'slug': 'sargeras',
#         'altSlug': 'sargeras',
#         'locale': 'fr_FR',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 10863698,
#        'persona_id': 2667774,
#        'name': 'Fayastrasza-10863698',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
# ...
#     'faction': 'alliance',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 3,
#       'icon': 'spell_shaman_lavasurge',
#       'name': 'Volcanic',
#       'description': 'While in combat, enemies periodically cause gouts of flame to erupt beneath the feet of distant players.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 326632,
#        'persona_id': 243877,
#        'name': 'Awsomeist-326632',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 11,
#         'name': 'Draenei',
#         'slug': 'draenei',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/sylvanas/Awsomeist-326632',
#        'realm': {'id': 716,
#         'connectedRealmId': 358,
#         'name': 'Sylvanas',
#         'altName': None,
#         'slug': 'sylvanas',
#         'altSlug': 'sylvanas',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 1166531,
#        'persona_id': 2670088,
#        'name': 'Dhuny-1166531',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Fury', 'slug': 'fury'},
#        'path': '/characters/eu/silvermoon/Dhuny-1166531',
#        'realm': {'id': 704,
#         'connectedRealmId': 355,
#         'name': 'Silvermoon',
#         'altName': None,
#         'slug': 'silvermoon',
#         'altSlug': 'silvermoon',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 5463933,
#        'persona_id': 3065928,
#        'name': 'Yabolish-5463933',
#        'class': {'id': 7, 'name': 'Shaman', 'slug': 'shaman'},
#        'race': {'id': 3,
#         'name': 'Dwarf',
#         'slug': 'dwarf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/eu/lordaeron/Yabolish-5463933',
#        'realm': {'id': 651,
#         'connectedRealmId': 341,
#         'name': 'Lordaeron',
#         'altName': None,
#         'slug': 'lordaeron',
#         'altSlug': 'lordaeron',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 7548075,
#        'persona_id': 3275968,
#        'name': 'Rooffee-7548075',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Fury', 'slug': 'fury'},
#        'path': '/characters/eu/frostmane/Rooffee-7548075',
#        'realm': {'id': 603,
#         'connectedRealmId': 324,
#         'name': 'Frostmane',
#         'altName': None,
#         'slug': 'frostmane',
#         'altSlug': 'frostmane',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10591495,
#        'persona_id': 2634986,
#        'name': 'Kazeshinu-10591495',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/ravencrest/Kazeshinu-10591495',
#        'realm': {'id': 689,
#         'connectedRealmId': 353,
#         'name': 'Ravencrest',
#         'altName': None,
#         'slug': 'ravencrest',
#         'altSlug': 'ravencrest',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 99,
#    'score': 287.2307308508363,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 1718125,
#     'keystone_team_id': 4838587,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1932114,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-10-05T22:54:29.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 168885,
#     'faction': 'alliance',
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 3,
#       'icon': 'spell_shaman_lavasurge',
#       'name': 'Volcanic',
#       'description': 'While in combat, enemies periodically cause gouts of flame to erupt beneath the feet of distant players.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 1305776,
#        'persona_id': 428459,
#        'name': 'Orangíe',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 11,
#         'name': 'Draenei',
#         'slug': 'draenei',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 120,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/us/emerald-dream/Orangíe',
#        'realm': {'id': 334,
#         'connectedRealmId': 185,
#         'name': 'Emerald Dream',
#         'altName': None,
#         'slug': 'emerald-dream',
#         'altSlug': 'emerald-dream',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'healer'},
#      {'character': {'id': 1475064,
#        'persona_id': 2398034,
#        'name': 'Zheckxd-1475064',
#        'class': {'id': 12, 'name': 'Demon Hunter', 'slug': 'demon-hunter'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Havoc', 'slug': 'havoc'},
#        'path': '/characters/us/emerald-dream/Zheckxd-1475064',
#        'realm': {'id': 334,
#         'connectedRealmId': 185,
#         'name': 'Emerald Dream',
#         'altName': None,
#         'slug': 'emerald-dream',
#         'altSlug': 'emerald-dream',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 5698816,
#        'persona_id': 3090206,
#        'name': 'Revelled-5698816',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 4,
#         'name': 'Night Elf',
#         'slug': 'night-elf',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/us/kelthuzad/Revelled-5698816',
#        'realm': {'id': 375,
#         'connectedRealmId': 209,
#         'name': "Kel'Thuzad",
#         'altName': None,
#         'slug': 'kelthuzad',
#         'altSlug': 'kelthuzad',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 9132871,
#        'persona_id': 2060637,
#        'name': 'Infektica-9132871',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 7,
#         'name': 'Gnome',
#         'slug': 'gnome',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/us/sargeras/Infektica-9132871',
#        'realm': {'id': 428,
#         'connectedRealmId': 231,
#         'name': 'Sargeras',
#         'altName': None,
#         'slug': 'sargeras',
#         'altSlug': 'sargeras',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10424031,
#        'persona_id': 1970039,
#        'name': 'Bigbadkevin-10424031',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 1,
#         'name': 'Human',
#         'slug': 'human',
#         'faction': 'alliance'},
#        'faction': 'alliance',
#        'level': 110,
#        'spec': {'name': 'Fury', 'slug': 'fury'},
#        'path': '/characters/us/emerald-dream/Bigbadkevin-10424031',
#        'realm': {'id': 334,
#         'connectedRealmId': 185,
#         'name': 'Emerald Dream',
#         'altName': None,
#         'slug': 'emerald-dream',
#         'altSlug': 'emerald-dream',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 100,
#    'score': 287.2007129330413,
#    'run': {'season': 'season-7.3.0',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999},
#     'keystone_run_id': 3466138,
#     'keystone_team_id': 6409224,
#     'keystone_platoon_id': None,
#     'mythic_level': 21,
#     'clear_time_ms': 1934747,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-12T21:14:20.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 166252,
#     'faction': 'horde',
#     'weekly_modifiers': [{'id': 5,
#       'icon': 'spell_nature_massteleport',
#       'name': 'Teeming',
#       'description': 'Additional non-boss enemies are present throughout the dungeon.'},
#      {'id': 4,
#       'icon': 'spell_deathknight_necroticplague',
#       'name': 'Necrotic',
#       'description': "All enemies' melee attacks apply a stacking blight that inflicts damage over time and reduces healing received."},
#      {'id': 9,
#       'icon': 'achievement_boss_archaedas',
#       'name': 'Tyrannical',
#       'description': 'Boss enemies have 40% more health and inflict up to 15% increased damage.'}],
#     'num_modifiers_active': 3,
#     'roster': [{'character': {'id': 3373840,
#        'persona_id': 949326,
#        'name': 'Drégan-3373840',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/draenor/Drégan-3373840',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4035264,
#        'persona_id': 1121564,
#        'name': 'Mithzz-4035264',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/twisting-nether/Mithzz-4035264',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 5530012,
#        'persona_id': 1459526,
#        'name': 'Drjaý-5530012',
#        'class': {'id': 8, 'name': 'Mage', 'slug': 'mage'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Fire', 'slug': 'fire'},
#        'path': '/characters/eu/twisting-nether/Drjaý-5530012',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 7503171,
#        'persona_id': 1861382,
#        'name': 'Sjeletyven-7503171',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 120,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/kazzak/Sjeletyven-7503171',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10823085,
#        'persona_id': 4560733,
#        'name': 'Hvick-10823085',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/the-maelstrom/Hvick-10823085',
#        'realm': {'id': 725,
#         'connectedRealmId': 297,
#         'name': 'The Maelstrom',
#         'altName': None,
#         'slug': 'the-maelstrom',
#         'altSlug': 'the-maelstrom',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'}},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}}],
#  'leaderboard_url': 'https://raider.io/mythic-plus-rankings/season-7.3.0/eye-of-azshara/world/leaderboards-strict',
#  'params': {'season': 'season-7.3.0',
#   'region': 'world',
#   'dungeon': 'eye-of-azshara',
#   'page': 4}}

# %%
legion_dungeons = ['black-rook-hold', 'cathedral-of-eternal-night', 'court-of-stars',
                   'darkheart-thicket', 'eye-of-azshara', 'halls-of-valor',
                   'maw-of-souls', 'neltharions-lair', 'return-to-karazhan-lower', 
                   'return-to-karazhan-upper', 'seat-of-the-triumvirate', 'the-arcway',
                   'vault-of-the-wardens']

legion_seasons = ['season-7.2.0', 'season-7.2.5', 'season-7.3.0', 'season-7.3.2',
                  'season-post-legion', 'season-pre-bfa']

bfa_dungeons = ['ataldazar', 'freehold', 'kings-rest', 'operation-mechagon-junkyard',
                'operation-mechagon-workshop', 'shrine-of-the-storm', 'siege-of-boralus',
                'temple-of-sethraliss', 'the-motherlode', 'the-underrot', 'tol-dagor',
                'waycrest-manor']

bfa_seasons = ['season-bfa-1', 'season-bfa-2', 'season-bfa-3',
               'season-bfa-3-post', 'season-bfa-4']

# %%
class RioScraper:
    
    def __init__(self, expansion, dungeons, seasons, regions):
        self.expansion = expansion
        self.dungeons = dungeons
        self.seasons = seasons
        self.regions = regions
        
        self.raw_data = []
        
    def construct_urls(self):
        base_url = 'https://raider.io/api/v1/mythic-plus/runs?'+\
                   'season={0}&region={1}&dungeon={2}&page={3}'
        
        urls = [base_url.format(season, region, dungeon, page)
                for season in self.seasons
                for region in self.regions
                for dungeon in self.dungeons
                for page in range(4)]
        return urls
                
    def query_rio(self, sleep_time=2.5):
        self.urls = self.construct_urls()
        for url in self.urls:
            response = requests.get(url)
            self.raw_data.append(response)
            time.sleep(sleep_time)

# %%
legion_scraper = RioScraper('Legion', legion_dungeons, legion_seasons, regions = ['us', 'eu', 'kr', 'tw', 'cn'])    
#legion_scraper.query_rio()

bfa_scraper = RioScraper('BFA', bfa_dungeons, bfa_seasons, regions = ['us', 'eu', 'kr', 'tw', 'cn'])    
#bfa_scraper.query_rio()

# %%
pickle.dump(legion_scraper.raw_data, open('data/legion_top100_runs_every_region_raw_resp.pkl', 'wb'))
pickle.dump(bfa_scraper.raw_data, open('data/bfa_top100_runs_every_region_raw_resp.pkl', 'wb'))

# %%
#x=pickle.load(open('legion_top100_runs_every_region_raw_resp.pkl', 'rb'))

# %%
unrolled = []
for item in resp_dict['rankings']:
    data = {}
    data['rank'] = item['rank']
    data['score'] = item['score']
    data['season'] = item['run']['season']
    data['patch'] = item['run']['dungeon']['short_name']
    data['dungeon'] = item['run']['dungeon']['short_name']
    data['faction'] = item['run']['faction']
    data['key_level'] = item['run']['mythic_level']
    
    affixes = [i['name'] for i in item['run']['weekly_modifiers']]
    data['affixes'] = '-'.join(affixes)

    dps = 0
    for index, character in enumerate(item['run']['roster']):
        char_role = character['role']
        if char_role == 'tank':
            dict_key = 'tank_'
        elif char_role == 'healer':
            dict_key = 'healer_'
        else:
            dict_key = 'dps%d_' % dps
            dps += 1

        data[dict_key+'name'] = character['character']['name']
        data[dict_key+'race'] = character['character']['race']['name']
        data[dict_key+'class'] = character['character']['class']['name']
        data[dict_key+'spec'] = character['character']['spec']['name']
        
    #unrolled.append(OrderedDict(data))
    unrolled.append(data)

# %%
df = pd.DataFrame(unrolled)

# %%
df.groupby('tank_class').count()
# Out:
#               affixes  dps0_class  dps0_name  dps0_race  dps0_spec  \
# tank_class
# Death Knight       11          11         11         11         11
# Demon Hunter        6           6          6          6          6
# Druid               1           1          1          1          1
# Monk                1           1          1          1          1
# Paladin             1           1          1          1          1
#
#               dps1_class  dps1_name  dps1_race  dps1_spec  dps2_class  \
# tank_class
# Death Knight          11         11         11         11          11
# Demon Hunter           6          6          6          6           6
# Druid                  1          1          1          1           1
# Monk                   1          1          1          1           1
# Paladin                1          1          1          1           1
#
#               dps2_name  dps2_race  dps2_spec  dungeon  faction  healer_class  \
# tank_class
# Death Knight         11         11         11       11       11            11
# Demon Hunter          6          6          6        6        6             6
# Druid                 1          1          1        1        1             1
# Monk                  1          1          1        1        1             1
# Paladin               1          1          1        1        1             1
#
#               healer_name  healer_race  healer_spec  key_level  patch  rank  \
# tank_class
# Death Knight           11           11           11         11     11    11
# Demon Hunter            6            6            6          6      6     6
# Druid                   1            1            1          1      1     1
# Monk                    1            1            1          1      1     1
# Paladin                 1            1            1          1      1     1
#
#               score  season  tank_name  tank_race  tank_spec
# tank_class
# Death Knight     11      11         11         11         11
# Demon Hunter      6       6          6          6          6
# Druid             1       1          1          1          1
# Monk              1       1          1          1          1
# Paladin           1       1          1          1          1
